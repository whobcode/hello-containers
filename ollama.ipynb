# %% [markdown]
# <a href="https://colab.research.google.com/github/whobcode/hello-containers/blob/main/ollama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DevSavvy: Run an Ollama Server on Google Colab & Expose via ngrok 🚀
#
# ## Step 1: Install Ollama ✅
# ### Ollama provides a simple API for managing LLMs.

# %%
# !curl -fsSL https://ollama.ai/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %% [markdown]
# ## Step 2: Install & Setup ngrok ✅
# ### Download and extract the latest ngrok binary

# %%
# !wget -q https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# !tar -xzf ngrok-v3-stable-linux-amd64.tgz ngrok

# %% [markdown]
# ## Authenticate ngrok
#
# * a ngrok auth token must be aquired in order to use it.
#
# * Follow the instruction below:
# https://ngrok.com/docs/getting-started/
#
# * Then replace your AuthToken with <NGROK_AUTH_TOKEN> below:

# %%
# !./ngrok authtoken 34aDC7DWAuVoxzYZ9FHF1lnfpwV_2hXpDp2WXKR6T4UQPYgh5
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %% [markdown]
# ## Step 3: Run Ollama & Expose API via ngrok 🚀
# ### Start the Ollama server in the background

# %%
# !ollama serve & ./ngrok http 11434 --host-header="localhost:11434" --log stdout & sleep 5s && ollama run whobcode/mother:latest
# Out:
# INFO[10-26|02:27:21] no configuration paths supplied
# INFO[10-26|02:27:21] using configuration at default config path path=/root/.config/ngrok/ngrok.yml
# INFO[10-26|02:27:21] open config file                         path=/root/.config/ngrok/ngrok.yml err=nil
# Couldn't find '/root/.ollama/id_ed25519'. Generating new private key.
# Your new public key is:
#
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIFlSO/5XmytUv6L1cXqrbEdH96oEGOcnHYZz4SaKv06A
#
# time=2025-10-26T02:27:21.495Z level=INFO source=routes.go:1511 msg="server config" env="map[CUDA_VISIBLE_DEVICES: GGML_VK_VISIBLE_DEVICES: GPU_DEVICE_ORDINAL: HIP_VISIBLE_DEVICES: HSA_OVERRIDE_GFX_VERSION: HTTPS_PROXY: HTTP_PROXY: NO_PROXY: OLLAMA_CONTEXT_LENGTH:4096 OLLAMA_DEBUG:INFO OLLAMA_FLASH_ATTENTION:false OLLAMA_GPU_OVERHEAD:0 OLLAMA_HOST:http://127.0.0.1:11434 OLLAMA_INTEL_GPU:false OLLAMA_KEEP_ALIVE:5m0s OLLAMA_KV_CACHE_TYPE: OLLAMA_LLM_LIBRARY: OLLAMA_LOAD_TIMEOUT:5m0s OLLAMA_MAX_LOADED_MODELS:0 OLLAMA_MAX_QUEUE:512 OLLAMA_MODELS:/root/.ollama/models OLLAMA_MULTIUSER_CACHE:false OLLAMA_NEW_ENGINE:false OLLAMA_NOHISTORY:false OLLAMA_NOPRUNE:false OLLAMA_NUM_PARALLEL:1 OLLAMA_ORIGINS:[http://localhost https://localhost http://localhost:* https://localhost:* http://127.0.0.1 https://127.0.0.1 http://127.0.0.1:* https://127.0.0.1:* http://0.0.0.0 https://0.0.0.0 http://0.0.0.0:* https://0.0.0.0:* app://* file://* tauri://* vscode-webview://* vscode-file://*] OLLAMA_REMOTES:[ollama.com] OLLAMA_SCHED_SPREAD:false ROCR_VISIBLE_DEVICES: http_proxy: https_proxy: no_proxy:]"
# time=2025-10-26T02:27:21.496Z level=INFO source=images.go:522 msg="total blobs: 0"
# time=2025-10-26T02:27:21.496Z level=INFO source=images.go:529 msg="total unused blobs removed: 0"
# time=2025-10-26T02:27:21.496Z level=INFO source=routes.go:1564 msg="Listening on 127.0.0.1:11434 (version 0.12.6)"
# time=2025-10-26T02:27:21.496Z level=INFO source=runner.go:80 msg="discovering available GPUs..."
# t=2025-10-26T02:27:21+0000 lvl=info msg="starting web service" obj=web addr=127.0.0.1:4040 allow_hosts=[]
# t=2025-10-26T02:27:21+0000 lvl=info msg="client session established" obj=tunnels.session
# t=2025-10-26T02:27:21+0000 lvl=info msg="tunnel session started" obj=tunnels.session
# time=2025-10-26T02:27:21.925Z level=INFO source=types.go:112 msg="inference compute" id=GPU-a58291d3-b8bf-8aab-63d3-c3d464863447 library=CUDA compute=7.5 name=CUDA0 description="Tesla T4" libdirs=ollama,cuda_v12 driver=12.4 pci_id=00:04.0 type=discrete total="15.0 GiB" available="14.7 GiB"
# time=2025-10-26T02:27:21.925Z level=INFO source=routes.go:1605 msg="entering low vram mode" "total vram"="15.0 GiB" threshold="20.0 GiB"
# t=2025-10-26T02:27:21+0000 lvl=info msg="started tunnel" obj=tunnels name=command_line addr=http://localhost:11434 url=https://untold-nonsequent-rayford.ngrok-free.dev
# [GIN] 2025/10/26 - 02:27:26 | 200 |      74.692µs |       127.0.0.1 | HEAD     "/"
# [GIN] 2025/10/26 - 02:27:26 | 404 |     305.751µs |       127.0.0.1 | POST     "/api/show"
# time=2025-10-26T02:27:27.273Z level=INFO source=download.go:177 msg="downloading 6be6d66a3f54 in 66 1 GB part(s)"
# time=2025-10-26T02:42:47.608Z level=INFO source=download.go:177 msg="downloading f60356777647 in 1 11 KB part(s)"
# time=2025-10-26T02:42:48.873Z level=INFO source=download.go:177 msg="downloading 5ec5cabe7fa7 in 1 9.8 KB part(s)"
# time=2025-10-26T02:42:50.145Z level=INFO source=download.go:177 msg="downloading b40808af010e in 1 11 KB part(s)"
# time=2025-10-26T02:42:51.413Z level=INFO source=download.go:177 msg="downloading 148adfc91973 in 1 331 B part(s)"
# time=2025-10-26T02:42:52.677Z level=INFO source=download.go:177 msg="downloading 0fa9ec509d6f in 1 564 B part(s)"
# t=2025-10-26T02:46:57+0000 lvl=info msg="received stop request" obj=app stopReq="{err:<nil> restart:false}"
# t=2025-10-26T02:46:58+0000 lvl=info msg="session closing" obj=tunnels.session err=nil
# ^C
